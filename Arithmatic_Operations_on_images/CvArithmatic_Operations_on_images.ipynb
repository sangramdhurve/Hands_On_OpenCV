# %% [markdown]
# <a href="https://colab.research.google.com/github/sangramdhurve/Hands_On_OpenCV/blob/main/Arithmatic_Operations_on_images/CvArithmatic_Operations_on_images.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Arithmmatic Operaitions
#
# Image Processing techniques take advantage of mathematical operations to achieve different result. Most often we arrive at an enhanced version of the image using some basic operations. We will take a look at some of the fundamental operations often used in computer vision pipelines. In this notebook we will cover Arithmetic Operations like addition and multiplication.

# %%
# Import Libraries
import cv2
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
# %matplotlib inline
from IPython.display import Image

# %% [markdown]
# #Orignal Image

# %%
img_bgr = cv2.imread("/content/drive/MyDrive/Python projects/OpenCV/SangramCV/Arithmatic_Operations_on_images/New_Zealand_Coast.jpg", cv2.IMREAD_COLOR)
img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb)
# Display 18x18 pixel image.
Image(filename="/content/drive/MyDrive/Python projects/OpenCV/SangramCV/Arithmatic_Operations_on_images/New_Zealand_Coast.jpg")

# %% [markdown]
# #Addition or Brightness
#
# The first operation we discuss is simple addition of images. This result in increasing or decreasing the brightness of the image since we are eventually increasing or decreasing the intensity values of each pixel by the same amount.
# So, this will result in a global increase/decrease in brightness.

# %%
matrix = np.ones(img_rgb.shape, dtype = 'uint8') * 50

img_rgb_brighter = cv2.add(img_rgb, matrix)
img_rgb_darker   = cv2.subtract(img_rgb, matrix)

#Show the images
plt.figure(figsize=[18,5])
plt.subplot(131);plt.imshow(img_rgb_darker);plt.title("Darker")
plt.subplot(132);plt.imshow(img_rgb);plt.title("Original")
plt.subplot(133);plt.imshow(img_rgb_brighter);plt.title("Brighter")
# Out:
# Text(0.5, 1.0, 'Brighter')

# %% [markdown]
# #Multiplication or Contrast
#
# Just like addition can result in brightness change, multiplication can be used to improve the contrast of the image.
#
# Contrast is the difference in the intensity values of the pixels of an image. Multiplying the intensity values with a constant can make the difference larger or smaller (if multiplying factor is < 1).

# %%
matrix1 = np.ones(img_rgb.shape) * .8
matrix2 = np.ones(img_rgb.shape) * 1.2

img_rgb_darker = np.uint8(cv2.multiply(np.float64(img_rgb), matrix1))
imag_rgb_lighter = np.uint8(cv2.multiply(np.float64(img_bgr), matrix2))
#Display the images
plt.figure(figsize=[18, 5])
plt.subplot(131);plt.imshow(img_rgb_darker);plt.title("Darker")
plt.subplot(132);plt.imshow(imag_rgb_lighter[:,:,::-1]);plt.title("lighter")
plt.subplot(133);plt.imshow(img_rgb);plt.title("Original")
# Out:
# Text(0.5, 1.0, 'Original')

# %% [markdown]
# #What happened?
# Can you see the weird colors in some areas of the image after multiplication?
#
# The issue is that after multiplying, the values which are already high, are becoming greater than 255. Thus the overflow issue. How do we overcome this?

# %% [markdown]
# #Handling Overflow using np.clip

# %%
martix1 = np.ones(img_rgb.shape) * .8
martix2 = np.ones(img_rgb.shape) * 1.2

img_rgb_lower = np.uint8(cv2.multiply(np.float64(img_rgb), matrix1))
img_rgb_higher = np.uint8(np.clip(cv2.multiply(np.float64(img_rgb), matrix2),0, 255))

#display the image
plt.figure(figsize=[18,6])
plt.subplot(131);plt.imshow(img_rgb_lower);plt.title("Lower")
plt.subplot(132);plt.imshow(img_rgb_higher);plt.title("Higher")
plt.subplot(133);plt.imshow(img_rgb);plt.title("Original")
# Out:
# Text(0.5, 1.0, 'Original')

# %% [markdown]
# #Thank you!
